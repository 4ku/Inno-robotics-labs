# %% [markdown]
# # SCARA robot with YZX spherical wrist

# %% [markdown]
# ![](Description.png)

# %% [markdown]
# ## Robot diagram

# %% [markdown]
# ![](https://github.com/4ku/Inno-robotics-labs/raw/master/Dynamics%20of%20non%20linear%20robotic%20systems/Assignment%201/SCARA_diagram.png)

# %% [markdown]
# ## Set points of trajectory

# %%
from matrix import Rx, Ry, Rz, T
from numpy import pi
import numpy as np
np.set_printoptions(suppress=True)


def rad(degree):
    # convert degrees to radian
    return pi/180 * degree


p0 = Rz(rad(0)) * Ry(rad(0)) * Rx(rad(0)) * T([0.5, 0.5, 0.5])
p1 = Rz(rad(30)) * Ry(rad(60)) * Rx(rad(80)) * T([1, 1, 1])
p2 = Rz(rad(50)) * Ry(rad(50)) * Rx(rad(70)) * T([0.5, 1.1, 1.2])
p3 = Rz(rad(40)) * Ry(rad(80)) * Rx(rad(10)) * T([0.7, 0.9, 0.4])
p = [p0, p1, p2, p3]

# %% [markdown]
# ## Inverse kimetics

# %%
from scara_kinematics import ScaraKinematics
scara = ScaraKinematics()
q0 = scara.inverse(p0)
q1 = scara.inverse(p1)
q2 = scara.inverse(p2)
q3 = scara.inverse(p3)
q = [q0, q1, q2, q3]

print("q0", q0)
print("q1", q1)
print("q2", q2)
print("q3", q3)
# Out:
# q0 (-3.565623693080534, 2.4188584057763776, 0.5, -0.0, 1.1467652873041563, -0.0)
# q1 (0.0, 3.141592653589793, 0.0, 2.0344439357957027, 2.8889123984477143, -2.208976860995136)
# q2 (-3.0518032041940613, 2.891043202665018, -0.4873937609935853, 1.1651049248824648, 0.5849901968596521, 0.31201814768818154)
# q3 (-3.6914156099864606, 2.4783760426799755, -0.18982091394525724, 1.629593572244054, -2.977166850559963, -1.7414845420299487)

# %% [markdown]
# ## Trajectory planning

# %% [markdown]
# Motion parameters:
# $\begin{equation}
# p = [q_0 , q_f, \dot q_{max}, \ddot q_{max}]
# \end{equation}$
#
# We are going to calculate trajectories using triangular or trapezoidal profile.
# **Profile is triangular if**
# $\begin{equation}
# \sqrt{\Delta q . \ddot q_{max}} \leq \dot q_{max}
# \end{equation}$
#
# For acceleration and deceleration time:
#
# $\begin{equation}
# \tau = \frac{\dot q_{max}}{\ddot q_{max}} \\
# \end{equation}$
#
# Dwelling time for trapezoidal profile:
# $\begin{equation}
# T = \frac{\Delta{q}}{\dot q_{max}} \\
# \Delta q = q_f - q_0
# \end{equation}$

# %% [markdown]
# Position trajectory equation:
# ![](Trapizoidal_profile.png)
# So we can use derivative to find velocity, and acceleration trajectory equations from position trajectory equation.

# %% [markdown]
# ### Numerical control

# %% [markdown]
# Robot can send signals at discrete period of time. So we should recalculate our to trajectories.

# %% [markdown]
# ![](Numerical_control.png)

# %% [markdown]
# **End-effector error**
# We assume that the final angles will be the same. Therefore, there should be no end effector mistake.

# %% [markdown]
# ### Trajectory junction

# %% [markdown]
# When we follow several points consistently, we don't want to lose our velocity, so we want to do it smoothly.

# %% [markdown]
# ![](Trajectory_junction.png)

# %%
from matplotlib import pyplot as plt
from numpy import pi
from joint import Joint

#convert degrees to radian 
def rad(degrees):
    return pi/180 * degrees

# points = np.array(q).T

# %%
j1 = Joint([0, 1], dq_max=0.1, ddq_max=0.1)
j2 = Joint([0.8, 0], 0.1, 0.05)
joints = [j1, j2]

# %%
for joint in joints:
    joint.calculate_path()

for joint in joints:
    joint.plot_path_points(print_points=True, convert_to_degrees=False)
# Out:
# Points:
#          №|         t|         q|         v
#          0|     0.000|     0.000|     0.000
#          1|     1.000|     0.050|     0.100
#          2|    10.000|     0.950|     0.100
#          3|    11.000|     1.000|     0.000
# Points:
#          №|         t|         q|         v
#          0|     0.000|     0.800|     0.000
#          1|     2.000|     0.700|    -0.100
#          2|     8.000|     0.100|    -0.100
#          3|    10.000|     0.000|     0.000

# %%
Joint.synchronization(joints)
for joint in joints:
    joint.plot_path_points(print_points=True, convert_to_degrees=False)
# Out:
# Points:
#          №|         t|         q|         v
#          0|     0.000|     0.000|     0.000
#          1|     2.000|     0.091|     0.091
#          2|    11.000|     0.909|     0.091
#          3|    13.000|     1.000|     0.000
# Points:
#          №|         t|         q|         v
#          0|     0.000|     0.800|     0.000
#          1|     2.000|     0.727|    -0.073
#          2|    11.000|     0.073|    -0.073
#          3|    13.000|     0.000|     0.000

# %% [markdown]
# ## Dynamics

# %% [markdown]
# ![](dynamics.png)

# %% [markdown]
# ### Robot scheme with masses

# %% [markdown]
# ![](Robot_scheme.png)

# %% [markdown]
# ### Initialize model params

# %%
import numpy as np
from sympy import *

q1, q2, d3, q4, q5, q6 = symbols("q1 q2 d3 q4 q5 q6")
dq1, dq2, dd3, dq4, dq5, dq6 = symbols("dq1, dq2, dd3, dq4, dq5, dq6")
ddq1, ddq2, ddd3, ddq4, ddq5, ddq6 = symbols("ddq1, ddq2, ddd3, ddq4, ddq5, ddq6")
q = Matrix([q1, q2, d3, q4, q5, q6])
dq = Matrix([dq1, dq2, dd3, dq4, dq5, dq6])
ddq = Matrix([ddq1, ddq2, ddd3, ddq4, ddq5, ddq6])

L1, L2 = symbols("L1 L2")
#Masses
m1, m2, m3, m4 = symbols("m1 m2 m3 m4")
m = [m1, m2, m3, m4]

# Tensor of inertia
Ix1, Iy1, Iz1, Ix2, Iy2, Iz2, Ix3, Iy3, Iz3, Ix4, Iy4, Iz4 = symbols("Ix1, Iy1, Iz1, Ix2, Iy2, Iz2, Ix3, Iy3, Iz3, Ix4, Iy4, Iz4")
I1 = Matrix([[Ix1, 0, 0], [0, Iy1, 0], [0, 0, Iz1]])
I2 = Matrix([[Ix2, 0, 0], [0, Iy2, 0], [0, 0, Iz2]])
I3 = Matrix([[Ix3, 0, 0], [0, Iy3, 0], [0, 0, Iz3]])
I4 = Matrix([[Ix4, 0, 0], [0, Iy4, 0], [0, 0, Iz4]])

# %% [markdown]
# ### Inertia matrix calculation

# %% [markdown]
# Formula for inertia matrix for our robot:

# %% [markdown]
# ![](Inertia.jpg)

# %% [markdown]
# #### Rotation matrices

# %% [markdown]
# Let's first calculate rotation matrices

# %%
R0 = Matrix([[1,0,0],[0,1,0],[0,0,1]])
R1z = Matrix([[cos(q1), -sin(q1), 0], [sin(q1) , cos(q1), 0], [0, 0, 1]])
R2z = Matrix([[cos(q2), -sin(q2), 0], [sin(q2) , cos(q2), 0], [0, 0, 1]])
R4y = Matrix([[cos(q4), 0, sin(q4)], [0 , 1, 0], [-sin(q4), 0, cos(q4)]])
R5z = Matrix([[cos(q5), -sin(q5), 0], [sin(q5) , cos(q5), 0], [0, 0, 1]])
R6x = Matrix([[1, 0, 0], [0 , cos(q6), -sin(q6)], [0, sin(q6), cos(q6)]])

R1 = R1z
R2 = simplify(R1z * R2z)
R4 = simplify(R1z * R2z * R4y)
R5 = simplify(R1z * R2z * R4y * R5z)
R = simplify(R1z * R2z * R4y * R5z * R6x)

# %% [markdown]
# #### Robot geometry

# %% [markdown]
# Let's calculate positions of each center of mass

# %% [markdown]
# ![](plot_c1.jpg)

# %% [markdown]
# Centers of mass for m2, m3, m4:

# %% [markdown]
# ![](c234.jpg)

# %% [markdown]
# #### Linear velocity Jacobians

# %% [markdown]
# Jacobians calculates with next formula

# %% [markdown]
# ![](JacV.jpg)

# %% [markdown]
# Lets' calculate linear velocity Jacobians for our robot

# %% [markdown]
# ![](Jv1.jpg)

# %% [markdown]
# ![](Jv2.jpg)

# %% [markdown]
# ![](Jv3_4.jpg)

# %%
Jv1 = np.zeros((3,6)).astype('object')
Jv1[0][0] = -0.5 * L1 * sin(q1)
Jv1[1][0] = 0.5 * L1 * cos(q1)
Jv1 = Matrix(Jv1)

Jv2 = np.zeros((3,6)).astype('object')
Jv2[0][0] = -L1 * sin(q1) - 0.5 * L2 * sin(q1 + q2)
Jv2[1][0] = L1 * cos(q1) + 0.5 * L2 * cos(q1 + q2)
Jv2[0][1] = -0.5 * L2 * sin(q1 + q2)
Jv2[1][1] = 0.5 * L2 * cos(q1 + q2)
Jv2 = Matrix(Jv2)

Jv3 = Jv2.copy()
Jv3[2,2] = 1/2

Jv4 = Jv2.copy()
Jv4[2,2] = 1
Jv = [Jv1, Jv2, Jv3, Jv4]

# %% [markdown]
# #### Angular velocity Jacobians

# %% [markdown]
# ![](Angular_Jac.jpg)

# %% [markdown]
# Angular Jacobians for our robot:

# %% [markdown]
# ![](Jw123.jpg)

# %% [markdown]
# ![](Jw4.jpg)

# %%
Jw1 = np.zeros((3,6)).astype('object')
Jw1[2][0] = 1
Jw1 = Matrix(Jw1)

Jw2 = Jw1.copy()
Jw2[2,1] = 1
Jw3 = Jw2.copy()
Jw4 = Jw2.copy()
Jw4[0, 3] = -sin(q1 + q2)
Jw4[0, 4] = sin(q4) * cos(q1 + q2)
Jw4[0, 5] = -sin(q5) * sin(q1+q2) + cos(q4) * cos(q5) * cos(q1 + q2)
Jw4[1, 3] = cos(q1 + q2)
Jw4[1, 4] = sin(q4) * sin(q1 + q2)
Jw4[1, 5] = sin(q5) * cos(q1+q2) + cos(q4) * cos(q5) * sin(q1 + q2)
Jw4[2, 3] = 0
Jw4[2, 4] = cos(q4)
Jw4[2, 5] = -sin(q4) * cos(q5)

# %% [markdown]
# ### Inertia matrix result

# %%
M1 = m1 * Jv1.T * Jv1 + Jw1.T * R1 * I1 * R1.T * Jw1
M2 = m2 * Jv2.T * Jv2 + Jw2.T * R2 * I2 * R2.T * Jw2
M3 = m3 * Jv3.T * Jv3 + Jw3.T * R2 * I3 * R2.T * Jw3
M4 = m4 * Jv4.T * Jv4 + Jw4.T * R2 * I4 * R4.T * Jw4
M = simplify(M1 + M2 + M3 + M4)

# %%
M
# Out:
# Matrix([
# [1.0*Iz1 + 1.0*Iz2 + 1.0*Iz3 + 1.0*Iz4*cos(q4) + 0.25*L1**2*m1 + 1.0*L1**2*m2 + 1.0*L1**2*m3 + 1.0*L1**2*m4 + 1.0*L1*L2*m2*cos(q2) + 1.0*L1*L2*m3*cos(q2) + 1.0*L1*L2*m4*cos(q2) + 0.25*L2**2*m2 + 0.25*L2**2*m3 + 0.25*L2**2*m4, 1.0*Iz2 + 1.0*Iz3 + 1.0*Iz4*cos(q4) + 0.5*L1*L2*m2*cos(q2) + 0.5*L1*L2*m3*cos(q2) + 0.5*L1*L2*m4*cos(q2) + 0.25*L2**2*m2 + 0.25*L2**2*m3 + 0.25*L2**2*m4,            0,           0,                  Iz4,                                             0],
# [                                                                       1.0*Iz2 + 1.0*Iz3 + 1.0*Iz4*cos(q4) + 0.5*L1*L2*m2*cos(q2) + 0.5*L1*L2*m3*cos(q2) + 0.5*L1*L2*m4*cos(q2) + 0.25*L2**2*m2 + 0.25*L2**2*m3 + 0.25*L2**2*m4,                                                                      1.0*Iz2 + 1.0*Iz3 + 1.0*Iz4*cos(q4) + 0.25*L2**2*m2 + 0.25*L2**2*m3 + 0.25*L2**2*m4,            0,           0,                  Iz4,                                             0],
# [                                                                                                                                                                                                                              0,                                                                                                                                                        0, 0.25*m3 + m4,           0,                    0,                                             0],
# [                                                                                                                                                                                                                              0,                                                                                                                                                        0,            0,         Iy4,                    0,                                   Iy4*sin(q5)],
# [                                                                                                                                                                                               -Ix4*sin(q4)**2 + Iz4*cos(q4)**2,                                                                                                                         -Ix4*sin(q4)**2 + Iz4*cos(q4)**2,            0,           0,          Iz4*cos(q4),                           Ix4*sin(q4)*cos(q5)],
# [                                                                                                                                                                               -(Ix4 + Iz4)*(sin(2*q4 - q5) + sin(2*q4 + q5))/4,                                                                                                         -(Ix4 + Iz4)*(sin(2*q4 - q5) + sin(2*q4 + q5))/4,            0, Iy4*sin(q5), -Iz4*sin(q4)*cos(q5), Ix4*cos(q4)*cos(q5)**2 - Iy4*cos(q5)**2 + Iy4]])

# %% [markdown]
# ### Coriolis matrix calculation

# %% [markdown]
# To find coriolis matrix:

# %% [markdown]
# ![](coriolis.png)

# %%
C = np.zeros((6,6)).astype('object')

for i in range(M.shape[0]):
    for j in range(M.shape[1]):
        for k in range(M.shape[0]):
            C[i][j] += 0.5 * (diff(M[i, j], q[k]) + diff(M[i, k], q[j]) - diff(M[j, k], q[i])) * dq[k]
C = simplify(Matrix(C))

# %%
C
# Out:
# Matrix([
# [                                            -0.5*Iz4*dq4*sin(q4) - 0.5*L1*L2*dq2*(m2 + m3 + m4)*sin(q2),      -0.5*Iz4*dq4*sin(q4) - 0.5*L1*L2*dq1*(m2 + m3 + m4)*sin(q2) - 0.5*L1*L2*dq2*(m2 + m3 + m4)*sin(q2), 0,                                                                                                                                                            -0.5*Iz4*(dq1 + dq2)*sin(q4),                                                                                                                                                                                                                                   0,                                                                                                                                                                                                                                            0],
# [                                            -0.5*Iz4*dq4*sin(q4) + 0.5*L1*L2*dq1*(m2 + m3 + m4)*sin(q2),                                                                                    -0.5*Iz4*dq4*sin(q4), 0,                                                                                                                                                            -0.5*Iz4*(dq1 + dq2)*sin(q4),                                                                                                                                                                                                                                   0,                                                                                                                                                                                                                                            0],
# [                                                                                                      0,                                                                                                       0, 0,                                                                                                                                                                                       0,                                                                                                                                                                                                                                   0,                                                                                                                                                                                                                                            0],
# [                                                                            0.5*Iz4*(dq1 + dq2)*sin(q4),                                                                             0.5*Iz4*(dq1 + dq2)*sin(q4), 0,                                                                                                                                                                                       0,                                                                                                           0.5*Iz4*dq5*sin(q4) + 0.5*dq1*(Ix4 + Iz4)*sin(2*q4) + 0.5*dq2*(Ix4 + Iz4)*sin(2*q4) - 0.5*dq6*(Ix4*cos(q4) - Iy4)*cos(q5),                                                       0.5*Ix4*dq6*sin(q4)*cos(q5)**2 + 0.25*dq1*(Ix4 + Iz4)*(cos(2*q4 - q5) + cos(2*q4 + q5)) + 0.25*dq2*(Ix4 + Iz4)*(cos(2*q4 - q5) + cos(2*q4 + q5)) + 0.5*dq5*(Iy4 + Iz4*cos(q4))*cos(q5)],
# [                                                                         -0.5*dq4*(Ix4 + Iz4)*sin(2*q4),                                                                          -0.5*dq4*(Ix4 + Iz4)*sin(2*q4), 0,                                                              -0.5*Iz4*dq5*sin(q4) - 0.5*dq1*(Ix4 + Iz4)*sin(2*q4) - 0.5*dq2*(Ix4 + Iz4)*sin(2*q4) + 0.5*dq6*(Ix4*cos(q4) - Iy4)*cos(q5),                                                                                                                                                                                                                -0.5*Iz4*dq4*sin(q4), -0.125*dq1*(Ix4 + Iz4)*(cos(2*q4 - q5) - cos(2*q4 + q5)) - 0.125*dq2*(Ix4 + Iz4)*(cos(2*q4 - q5) - cos(2*q4 + q5)) + 0.5*dq4*(Ix4*cos(q4) - Iy4)*cos(q5) - 0.5*dq5*(Ix4 + Iz4)*sin(q4)*sin(q5) + 1.0*dq6*(Ix4*cos(q4) - Iy4)*sin(q5)*cos(q5)],
# [(Ix4 + Iz4)*(-0.25*dq4*(cos(2*q4 - q5) + cos(2*q4 + q5)) + 0.125*dq5*(cos(2*q4 - q5) - cos(2*q4 + q5))), (Ix4 + Iz4)*(-0.25*dq4*(cos(2*q4 - q5) + cos(2*q4 + q5)) + 0.125*dq5*(cos(2*q4 - q5) - cos(2*q4 + q5))), 0, -0.5*Ix4*dq6*sin(q4)*cos(q5)**2 - 0.25*dq1*(Ix4 + Iz4)*(cos(2*q4 - q5) + cos(2*q4 + q5)) - 0.25*dq2*(Ix4 + Iz4)*(cos(2*q4 - q5) + cos(2*q4 + q5)) + 0.5*dq5*(Iy4 - Iz4*cos(q4))*cos(q5), 1.0*Iz4*dq5*sin(q4)*sin(q5) + 0.125*dq1*(Ix4 + Iz4)*(cos(2*q4 - q5) - cos(2*q4 + q5)) + 0.125*dq2*(Ix4 + Iz4)*(cos(2*q4 - q5) - cos(2*q4 + q5)) + 0.5*dq4*(Iy4 - Iz4*cos(q4))*cos(q5) - 1.0*dq6*(Ix4*cos(q4) - Iy4)*sin(q5)*cos(q5),                                                                                                                                                                 -(0.5*Ix4*dq4*sin(q4)*cos(q5) + 1.0*dq5*(Ix4*cos(q4) - Iy4)*sin(q5))*cos(q5)]])

# %% [markdown]
# ### Gravity vector calculation

# %% [markdown]
# To find gravity vector:

# %% [markdown]
# ![](gravity.jpg)

# %%
g0 = symbols("g0")
g = np.zeros(6).astype('object')
for i in range(6):
    for k in range(len(Jv)):
        g[i] -= Jv[k][2, i] * m[k] * g0
g = Matrix(g)

# %%
g
# Out:
# Matrix([
# [                 0],
# [                 0],
# [-0.5*g0*m3 - g0*m4],
# [                 0],
# [                 0],
# [                 0]])

# %% [markdown]
# ### Final dynamic model

# %%
T = simplify(M * ddq + C * dq + g)

# %%
T.T
# Out:
# Matrix([[Iz4*ddq5 - 0.5*Iz4*dq4*(dq1 + dq2)*sin(q4) + ddq1*(1.0*Iz1 + 1.0*Iz2 + 1.0*Iz3 + 1.0*Iz4*cos(q4) + 0.25*L1**2*m1 + 1.0*L1**2*m2 + 1.0*L1**2*m3 + 1.0*L1**2*m4 + 1.0*L1*L2*m2*cos(q2) + 1.0*L1*L2*m3*cos(q2) + 1.0*L1*L2*m4*cos(q2) + 0.25*L2**2*m2 + 0.25*L2**2*m3 + 0.25*L2**2*m4) + ddq2*(1.0*Iz2 + 1.0*Iz3 + 1.0*Iz4*cos(q4) + 0.5*L1*L2*m2*cos(q2) + 0.5*L1*L2*m3*cos(q2) + 0.5*L1*L2*m4*cos(q2) + 0.25*L2**2*m2 + 0.25*L2**2*m3 + 0.25*L2**2*m4) - 0.5*dq1*(Iz4*dq4*sin(q4) + L1*L2*dq2*(m2 + m3 + m4)*sin(q2)) - 0.5*dq2*(Iz4*dq4*sin(q4) + L1*L2*dq1*(m2 + m3 + m4)*sin(q2) + L1*L2*dq2*(m2 + m3 + m4)*sin(q2)), Iz4*ddq5 - 0.5*Iz4*dq2*dq4*sin(q4) - 0.5*Iz4*dq4*(dq1 + dq2)*sin(q4) + ddq1*(1.0*Iz2 + 1.0*Iz3 + 1.0*Iz4*cos(q4) + 0.5*L1*L2*m2*cos(q2) + 0.5*L1*L2*m3*cos(q2) + 0.5*L1*L2*m4*cos(q2) + 0.25*L2**2*m2 + 0.25*L2**2*m3 + 0.25*L2**2*m4) + ddq2*(1.0*Iz2 + 1.0*Iz3 + 1.0*Iz4*cos(q4) + 0.25*L2**2*m2 + 0.25*L2**2*m3 + 0.25*L2**2*m4) - 0.5*dq1*(Iz4*dq4*sin(q4) - L1*L2*dq1*(m2 + m3 + m4)*sin(q2)), ddd3*(0.25*m3 + m4) - 0.5*g0*m3 - g0*m4, Iy4*ddq4 + Iy4*ddq6*sin(q5) + 0.5*Iz4*dq1*(dq1 + dq2)*sin(q4) + 0.5*Iz4*dq2*(dq1 + dq2)*sin(q4) + 0.5*dq5*(Iz4*dq5*sin(q4) + dq1*(Ix4 + Iz4)*sin(2*q4) + dq2*(Ix4 + Iz4)*sin(2*q4) - dq6*(Ix4*cos(q4) - Iy4)*cos(q5)) + dq6*(0.5*Ix4*dq6*sin(q4)*cos(q5)**2 + 0.25*dq1*(Ix4 + Iz4)*(cos(2*q4 - q5) + cos(2*q4 + q5)) + 0.25*dq2*(Ix4 + Iz4)*(cos(2*q4 - q5) + cos(2*q4 + q5)) + 0.5*dq5*(Iy4 + Iz4*cos(q4))*cos(q5)), Ix4*ddq6*sin(q4)*cos(q5) + Iz4*ddq5*cos(q4) - 0.5*Iz4*dq4*dq5*sin(q4) - ddq1*(Ix4*sin(q4)**2 - Iz4*cos(q4)**2) - ddq2*(Ix4*sin(q4)**2 - Iz4*cos(q4)**2) - 0.5*dq1*dq4*(Ix4 + Iz4)*sin(2*q4) - 0.5*dq2*dq4*(Ix4 + Iz4)*sin(2*q4) - 0.5*dq4*(Iz4*dq5*sin(q4) + dq1*(Ix4 + Iz4)*sin(2*q4) + dq2*(Ix4 + Iz4)*sin(2*q4) - dq6*(Ix4*cos(q4) - Iy4)*cos(q5)) - dq6*(0.125*dq1*(Ix4 + Iz4)*(cos(2*q4 - q5) - cos(2*q4 + q5)) + 0.125*dq2*(Ix4 + Iz4)*(cos(2*q4 - q5) - cos(2*q4 + q5)) - 0.5*dq4*(Ix4*cos(q4) - Iy4)*cos(q5) + 0.5*dq5*(Ix4 + Iz4)*sin(q4)*sin(q5) - 1.0*dq6*(Ix4*cos(q4) - Iy4)*sin(q5)*cos(q5)), Iy4*ddq4*sin(q5) - Iz4*ddq5*sin(q4)*cos(q5) - ddq1*(Ix4 + Iz4)*(sin(2*q4 - q5) + sin(2*q4 + q5))/4 - ddq2*(Ix4 + Iz4)*(sin(2*q4 - q5) + sin(2*q4 + q5))/4 + ddq6*(Ix4*cos(q4)*cos(q5)**2 - Iy4*cos(q5)**2 + Iy4) - dq1*(Ix4 + Iz4)*(0.25*dq4*(cos(2*q4 - q5) + cos(2*q4 + q5)) - 0.125*dq5*(cos(2*q4 - q5) - cos(2*q4 + q5))) - dq2*(Ix4 + Iz4)*(0.25*dq4*(cos(2*q4 - q5) + cos(2*q4 + q5)) - 0.125*dq5*(cos(2*q4 - q5) - cos(2*q4 + q5))) - dq4*(0.5*Ix4*dq6*sin(q4)*cos(q5)**2 + 0.25*dq1*(Ix4 + Iz4)*(cos(2*q4 - q5) + cos(2*q4 + q5)) + 0.25*dq2*(Ix4 + Iz4)*(cos(2*q4 - q5) + cos(2*q4 + q5)) - 0.5*dq5*(Iy4 - Iz4*cos(q4))*cos(q5)) + dq5*(1.0*Iz4*dq5*sin(q4)*sin(q5) + 0.125*dq1*(Ix4 + Iz4)*(cos(2*q4 - q5) - cos(2*q4 + q5)) + 0.125*dq2*(Ix4 + Iz4)*(cos(2*q4 - q5) - cos(2*q4 + q5)) + 0.5*dq4*(Iy4 - Iz4*cos(q4))*cos(q5) - 1.0*dq6*(Ix4*cos(q4) - Iy4)*sin(q5)*cos(q5)) - dq6*(0.5*Ix4*dq4*sin(q4)*cos(q5) + 1.0*dq5*(Ix4*cos(q4) - Iy4)*sin(q5))*cos(q5)]])

# %% [markdown]
# ### Put constants to equation

# %% [markdown]
# Let's put constants to equation to simplify our dynamic model

# %%
init_params = {L1: 1, L2: 1,
               m1: 1, m2: 1, m3: 1, m4: 1,
               Ix1: 1, Iy1: 1, Iz1: 1, Ix2: 1, Iy2: 1, Iz2: 1, Ix3: 1, Iy3: 1, Iz3: 1, Ix4: 1, Iy4: 1, Iz4: 1,
               g0: 9.8}
T_q = simplify(T.evalf(subs=init_params))
T_q.T
# Out:
# Matrix([[3.0*ddq1*cos(q2) + 1.0*ddq1*cos(q4) + 7.0*ddq1 + 1.5*ddq2*cos(q2) + 1.0*ddq2*cos(q4) + 2.75*ddq2 + 1.0*ddq5 - 3.0*dq1*dq2*sin(q2) - 1.0*dq1*dq4*sin(q4) - 1.5*dq2**2*sin(q2) - 1.0*dq2*dq4*sin(q4), 1.5*ddq1*cos(q2) + 1.0*ddq1*cos(q4) + 2.75*ddq1 + 1.0*ddq2*cos(q4) + 2.75*ddq2 + 1.0*ddq5 + 1.5*dq1**2*sin(q2) - 1.0*dq1*dq4*sin(q4) - 1.0*dq2*dq4*sin(q4), 1.25*ddd3 - 14.7, ddq4 + ddq6*sin(q5) + 0.5*dq1*(dq1 + dq2)*sin(q4) + 0.5*dq2*(dq1 + dq2)*sin(q4) + 0.5*dq5*(2.0*dq1*sin(2*q4) + 2.0*dq2*sin(2*q4) + dq5*sin(q4) - dq6*(cos(q4) - 1.0)*cos(q5)) + 0.5*dq6*(4.0*dq1*cos(q4)**2 - 2.0*dq1 + 4.0*dq2*cos(q4)**2 - 2.0*dq2 + 1.0*dq5*cos(q4) + 1.0*dq5 + 1.0*dq6*sin(q4)*cos(q5))*cos(q5), 1.0*ddq1*cos(2*q4) + 1.0*ddq2*cos(2*q4) + 1.0*ddq5*cos(q4) + 0.5*ddq6*sin(q4 - q5) + 0.5*ddq6*sin(q4 + q5) - 2.0*dq1*dq4*sin(2*q4) - 0.25*dq1*dq6*cos(2*q4 - q5) + 0.25*dq1*dq6*cos(2*q4 + q5) - 2.0*dq2*dq4*sin(2*q4) - 0.25*dq2*dq6*cos(2*q4 - q5) + 0.25*dq2*dq6*cos(2*q4 + q5) - 1.0*dq4*dq5*sin(q4) - 1.0*dq4*dq6*cos(q5) + 0.5*dq4*dq6*cos(q4 - q5) + 0.5*dq4*dq6*cos(q4 + q5) - 0.5*dq5*dq6*cos(q4 - q5) + 0.5*dq5*dq6*cos(q4 + q5) - 0.5*dq6**2*sin(2*q5) - 0.25*dq6**2*sin(q4 - 2*q5) + 0.25*dq6**2*sin(q4 + 2*q5), -0.5*ddq1*sin(2*q4 - q5) - 0.5*ddq1*sin(2*q4 + q5) - 0.5*ddq2*sin(2*q4 - q5) - 0.5*ddq2*sin(2*q4 + q5) + 1.0*ddq4*sin(q5) - 1.0*ddq5*sin(q4)*cos(q5) + 1.0*ddq6*cos(q4)*cos(q5)**2 - 1.0*ddq6*cos(q5)**2 + 1.0*ddq6 - 1.0*dq1*dq4*cos(2*q4 - q5) - 1.0*dq1*dq4*cos(2*q4 + q5) + 0.5*dq1*dq5*cos(2*q4 - q5) - 0.5*dq1*dq5*cos(2*q4 + q5) - 1.0*dq2*dq4*cos(2*q4 - q5) - 1.0*dq2*dq4*cos(2*q4 + q5) + 0.5*dq2*dq5*cos(2*q4 - q5) - 0.5*dq2*dq5*cos(2*q4 + q5) - 1.0*dq4*dq5*cos(q4)*cos(q5) + 1.0*dq4*dq5*cos(q5) - 1.0*dq4*dq6*sin(q4)*cos(q5)**2 + 1.0*dq5**2*sin(q4)*sin(q5) + 0.5*dq5*dq6*(sin(q4 - 2*q5) - sin(q4 + 2*q5)) + 1.0*dq5*dq6*sin(2*q5)]])

# %% [markdown]
# ### Find torques and plot graphs

# %%
def plot_torque(T_q, T, Q, V, A):
    torques = []
    
    for i in range(len(T[0])):
        params = {}
        for j in range(len(Q)):
            params[q[j]] = Q[j][i]
            params[dq[j]] = V[j][i]
            params[ddq[j]] = A[j][i]
        
        T_res = T_q.evalf(subs=params)
        torques.append(np.array(T_res)[:, 0])
    
    torques = np.array(torques)

    for i in range(len(Q)):
        plt.figure(figsize=(8, 6))
        plt.plot(T[i], torques[:, i])
        plt.show()

# %%
T, Q, V, A = [], [], [], []
for joint in joints:
    t, q_, v, a = joint.get_path_points_for_plot()
    T.append(t)
    Q.append(q_)
    V.append(v)
    A.append(a)
    
plot_torque(T_q, T, Q, V, A)
